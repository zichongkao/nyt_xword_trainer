# %%
import pandas as pd
from datetime import date, timedelta

def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
df = pd.read_csv('./bydatestore_xwordinfo.csv',  na_filter=False) # There are some clues with "NULL" as the answer.

# %%
df.head()
# Out:
#    year  month  day  weekday                           clue       answer  \
# 0  1993     11   21        6  Site of the Shandog Peninsula    YELLOWSEA
# 1  1993     11   21        6       "Closer to Fine" singers  INDIGOGIRLS
# 2  1993     11   21        6          Capital near Lake Tuz       ANKARA
# 3  1993     11   21        6               MasterCard rival       OPTIMA
# 4  1993     11   21        6                 Petrarch works      SONNETS
#
#        index
# 0   1-ACROSS
# 1   5-ACROSS
# 2  11-ACROSS
# 3  17-ACROSS
# 4  19-ACROSS

# %%
len(df)
# Out:
# 875542

# %% [markdown]
# ## Checks

# %%
# Ensure there are no duplicates
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [year, month, day, weekday, clue, answer, index]
# Index: []

# %%
grouped = df.groupby(['year','month','day'])
print(len(grouped))

# Check all dates covered
start_date = date(1993, 11, 21)
end_date = date(2022, 8, 1)
for single_date in daterange(start_date, end_date):
    if (single_date.year, single_date.month, single_date.day) not in grouped.groups.keys():
        print(single_date.strftime('%m/%d/%y'))
# Out:
# 10480

# %% [markdown]
# ## Fix mistake

# %%
def fix_missing_downs(gdf):
    oneacrosses = gdf[gdf['index'] == '1-ACROSS'].index
    if len(oneacrosses) == 2:
        downstart = oneacrosses[1]
        gdf.loc[downstart:,'index'] = gdf.loc[downstart:,'index'].apply(lambda x: x.replace('ACROSS', 'DOWN'))
    return gdf

# %%
res_df = grouped.apply(fix_missing_downs)

# %%
len(res_df)
# Out:
# 875542

# %%
res_df[(res_df['year'] == 2008) & (res_df['month'] == 1) & (res_df['day'] == 1)]
# Out:
#         year  month  day  weekday                                    clue  \
# 814425  2008      1    1        1                       "Mamma Mia" group
# 814426  2008      1    1        1                          Play chauffeur
# 814427  2008      1    1        1  Money to help one through a tight spot
# 814428  2008      1    1        1        Either of two directing brothers
# 814429  2008      1    1        1                     All gone, as dinner
# ...      ...    ...  ...      ...                                     ...
# 814498  2008      1    1        1                A couple of chips, maybe
# 814499  2008      1    1        1                         Injury reminder
# 814500  2008      1    1        1                 Purchases for a shindig
# 814501  2008      1    1        1               ___ 9000, sci-fi computer
# 814502  2008      1    1        1                    Bit of air pollution
#
#        answer      index
# 814425   ABBA   1-ACROSS
# 814426  DRIVE   5-ACROSS
# 814427   LOAN  10-ACROSS
# 814428   COEN  14-ACROSS
# 814429  EATEN  15-ACROSS
# ...       ...        ...
# 814498   ANTE    54-DOWN
# 814499   SCAR    55-DOWN
# 814500   KEGS    56-DOWN
# 814501    HAL    58-DOWN
# 814502    ASH    59-DOWN
#
# [78 rows x 7 columns]

# %%
tres_df = res_df.sort_values(['year','month','day']).reset_index()

# %%
tres_df.head()
# Out:
#    level_0  year  month  day  weekday                           clue  \
# 0        0  1993     11   21        6  Site of the Shandog Peninsula
# 1        1  1993     11   21        6       "Closer to Fine" singers
# 2        2  1993     11   21        6          Capital near Lake Tuz
# 3        3  1993     11   21        6               MasterCard rival
# 4        4  1993     11   21        6                 Petrarch works
#
#         answer      index
# 0    YELLOWSEA   1-ACROSS
# 1  INDIGOGIRLS   5-ACROSS
# 2       ANKARA  11-ACROSS
# 3       OPTIMA  17-ACROSS
# 4      SONNETS  19-ACROSS

# %%
tres_df[(tres_df['year'] == 2008) & (tres_df['month'] == 1) & (tres_df['day'] == 1)]
# Out:
#         level_0  year  month  day  weekday  \
# 432083   814425  2008      1    1        1
# 432084   814426  2008      1    1        1
# 432085   814427  2008      1    1        1
# 432086   814428  2008      1    1        1
# 432087   814429  2008      1    1        1
# ...         ...   ...    ...  ...      ...
# 432156   814498  2008      1    1        1
# 432157   814499  2008      1    1        1
# 432158   814500  2008      1    1        1
# 432159   814501  2008      1    1        1
# 432160   814502  2008      1    1        1
#
#                                           clue answer      index
# 432083                       "Mamma Mia" group   ABBA   1-ACROSS
# 432084                          Play chauffeur  DRIVE   5-ACROSS
# 432085  Money to help one through a tight spot   LOAN  10-ACROSS
# 432086        Either of two directing brothers   COEN  14-ACROSS
# 432087                     All gone, as dinner  EATEN  15-ACROSS
# ...                                        ...    ...        ...
# 432156                A couple of chips, maybe   ANTE    54-DOWN
# 432157                         Injury reminder   SCAR    55-DOWN
# 432158                 Purchases for a shindig   KEGS    56-DOWN
# 432159               ___ 9000, sci-fi computer    HAL    58-DOWN
# 432160                    Bit of air pollution    ASH    59-DOWN
#
# [78 rows x 8 columns]

# %%
tres_df.drop('level_0', axis=1, inplace=True)
tres_df.head()
# Out:
#    year  month  day  weekday                           clue       answer  \
# 0  1993     11   21        6  Site of the Shandog Peninsula    YELLOWSEA
# 1  1993     11   21        6       "Closer to Fine" singers  INDIGOGIRLS
# 2  1993     11   21        6          Capital near Lake Tuz       ANKARA
# 3  1993     11   21        6               MasterCard rival       OPTIMA
# 4  1993     11   21        6                 Petrarch works      SONNETS
#
#        index
# 0   1-ACROSS
# 1   5-ACROSS
# 2  11-ACROSS
# 3  17-ACROSS
# 4  19-ACROSS

# %%
tres_df.to_csv('./bydatestore_xwordinfo.csv', index=False)

# %% [markdown]
# ## Prepare Answer Counts and Ranks

# %%
count_df = pd.DataFrame(df.groupby('answer')['clue'].count())
count_df.columns = ['answer_count']
count_df['answer_rank'] = count_df['answer_count'].rank(method='min', ascending=False)

# %%
count_df.sort_values('answer_count', ascending=False)
# Out:
#              answer_count  answer_rank
# answer
# ERA                   659          1.0
# AREA                  550          2.0
# ERE                   532          3.0
# ONE                   524          4.0
# ELI                   509          5.0
# ...                   ...          ...
# JACOBASTOR              1      62178.0
# JACKY                   1      62178.0
# JACKWEBB                1      62178.0
# JACKTRIPPER             1      62178.0
# ZZZQUIL                 1      62178.0
#
# [120248 rows x 2 columns]

# %%
big_df = pd.merge(
    df,
    count_df,
    how="left",
    on="answer",
    copy=True,
    indicator=False,
    validate=None,
)
big_df.head()
# Out:
#    year  month  day  weekday                           clue       answer  \
# 0  1993     11   21        6  Site of the Shandog Peninsula    YELLOWSEA
# 1  1993     11   21        6       "Closer to Fine" singers  INDIGOGIRLS
# 2  1993     11   21        6          Capital near Lake Tuz       ANKARA
# 3  1993     11   21        6               MasterCard rival       OPTIMA
# 4  1993     11   21        6                 Petrarch works      SONNETS
#
#        index  answer_count  answer_rank
# 0   1-ACROSS             6      22799.0
# 1   5-ACROSS             5      25810.0
# 2  11-ACROSS            35       5248.0
# 3  17-ACROSS            16      10860.0
# 4  19-ACROSS            10      15790.0

# %%
big_df.tail()
# Out:
#         year  month  day  weekday                     clue answer     index  \
# 875537  2022      7   31        6       Inits. on the road    MPH  108-DOWN
# 875538  2022      7   31        6       Inits. on the road    AAA  109-DOWN
# 875539  2022      7   31        6  Darkroom item, in brief    NEG  110-DOWN
# 875540  2022      7   31        6        Personal ad abbr.    SWF  111-DOWN
# 875541  2022      7   31        6         No-win situation    TIE  112-DOWN
#
#         answer_count  answer_rank
# 875537            56       3009.0
# 875538           203        256.0
# 875539            52       3295.0
# 875540            13      12868.0
# 875541           240        146.0

# %%
display(big_df.dtypes)
big_df[big_df['answer_count'].isna()]
# Out:
# year              int64
# month             int64
# day               int64
# weekday           int64
# clue             object
# answer           object
# index            object
# answer_count      int64
# answer_rank     float64
# dtype: object
# Empty DataFrame
# Columns: [year, month, day, weekday, clue, answer, index, answer_count, answer_rank]
# Index: []

# %%
big_df['answer_count'] = big_df['answer_count'].astype(int)
big_df['answer_rank'] = big_df['answer_rank'].astype(int)

# %%
big_df.head()
# Out:
#    year  month  day  weekday                           clue       answer  \
# 0  1993     11   21        6  Site of the Shandog Peninsula    YELLOWSEA
# 1  1993     11   21        6       "Closer to Fine" singers  INDIGOGIRLS
# 2  1993     11   21        6          Capital near Lake Tuz       ANKARA
# 3  1993     11   21        6               MasterCard rival       OPTIMA
# 4  1993     11   21        6                 Petrarch works      SONNETS
#
#        index  answer_count  answer_rank
# 0   1-ACROSS             6        22799
# 1   5-ACROSS             5        25810
# 2  11-ACROSS            35         5248
# 3  17-ACROSS            16        10860
# 4  19-ACROSS            10        15790

# %%
big_df.to_csv('./bydatestore_xwordinfo_processed.csv', index=False)
